# %% [markdown]
# <div align="center">
# <a href="https://vbti.nl"><img src="images/vbti_logo.png" width="400"></a>
# </div>
#
# # Welcome!
#
# Welcome to the 1-day masterclass "Deep Learning" provided by [VBTI](https://vbti.nl). During this masterclass you will get an overview of the latest developments in the field of Artificial Intelligence / Deep Learning. These notebooks let you explore some AI topics by yourself. They are not ment to be a full in-depth course, but rather should give you a flavor of different deep learning techniques.
#
# You can change and experiment with the code as much as you like. However, no changes are saved when you exit the notebooks!
#
#
# # Topics
#
# During the masterclass you will learn more about the following AI techniques (click on the link to open the notebook):
#
#
# ### [Jupyter notebook](01_Jupyter.ipynb)
# A short introduction to Jupyter and Python. Both are standard tools for doing data science and Artificial Intelligence projects.
#
#
# ### [Artificial Neural Networks](02_ArtificialNeuralNetworks.ipynb)
# In this notebook you will train a specific artificial neural network, called a multi-layer perceptron.
# <div align="center">
# <img src="images/ann.png" width="400">
# </div>
#
#
# ### [Convolutional Neural Networks](03_ConvolutionalNeuralNetworks.ipynb)
# Convolutional neural networks are used for processing image data. In this notebook you will train a CNN to classify images.
# <div align="center">
# <img src="images/cnn.png" width="400">
# </div>
#
# ### [Recurrent Neural Networks](04_RecurrentNeuralNetworks.ipynb)
# Recurrent Neural Networks have a memory, which makes suitable for processing time series data.
# <div align="center">
# <img src="images/rnn.png" width="400">
# </div>
#
# ### [Reinforcement Learning](05_ReinforcementLearning.ipynb)
# Reinforcement learning is a technique to learn an optimal sequence of action that some criterium. RL is well known from applying them to games such as chess and Go.
# <div align="center">
# <img src="images/rl.png" width="400">
# </div>
